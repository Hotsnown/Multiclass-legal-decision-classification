# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.models import Sequential
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split
from src.features.build_features import *

labels = build_labels()
X = build_tokens()

SEED = 0
X_train, X_test, y_train, y_test = train_test_split(X , labels, test_size=0.25, random_state=SEED)

print("Train: N = {0} records".format(len(X_train)))
print("Test:  N = {0} records".format(len(X_test)))
# Out:
#                           ID  \
# 0       JURITEXT000037337794
# 1       JURITEXT000037337781
# 2       JURITEXT000037337786
# 3       JURITEXT000037337797
# 4       JURITEXT000037337795
# 5       JURITEXT000037337787
# 6       JURITEXT000037337789
# 7       JURITEXT000037337783
# 8       JURITEXT000037337788
# 9       JURITEXT000037337790
# 10      JURITEXT000037337784
# 11      JURITEXT000037337785
# 12      JURITEXT000037337796
# 13      JURITEXT000037337780
# 14      JURITEXT000037337782
# 15      JURITEXT000037384183
# 16      JURITEXT000038194514
# 17      JURITEXT000038194507
# 18      JURITEXT000038194523
# 19      JURITEXT000038194548
# 20      JURITEXT000038194524
# 21      JURITEXT000038264920
# 22      JURITEXT000038264932
# 23      JURITEXT000038508059
# 24      JURITEXT000038508038
# 25      JURITEXT000038508004
# 26      JURITEXT000038508067
# 27      JURITEXT000038508046
# 28      JURITEXT000038508077
# 29      JURITEXT000038508053
# ...                      ...
# 247401  JURITEXT000038322192
# 247402  JURITEXT000038567374
# 247403  JURITEXT000038567372
# 247404  JURITEXT000038567360
# 247405  JURITEXT000038567377
# 247406  JURITEXT000038567368
# 247407  JURITEXT000038567381
# 247408  JURITEXT000038567359
# 247409  JURITEXT000038567375
# 247410  JURITEXT000038567358
# 247411  JURITEXT000038567376
# 247412  JURITEXT000038567380
# 247413  JURITEXT000038567367
# 247414  JURITEXT000038567361
# 247415  JURITEXT000038567362
# 247416  JURITEXT000038567370
# 247417  JURITEXT000038567379
# 247418  JURITEXT000038567383
# 247419  JURITEXT000038567363
# 247420  JURITEXT000038567364
# 247421  JURITEXT000038567351
# 247422  JURITEXT000038567371
# 247423  JURITEXT000038567369
# 247424  JURITEXT000038567366
# 247425  JURITEXT000038567382
# 247426  JURITEXT000038567373
# 247427  JURITEXT000038567365
# 247428  JURITEXT000038567378
# 247429  JURITEXT000038345823
# 247430  JURITEXT000037362711
#
#                                                   contenu           formation  \
# 0       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 1       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 2       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 3       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 4       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 5       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 6       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 7       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 8       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 9       LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 10      LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 11      LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 12      LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 13      LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 14      LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 15      LA COUR DE CASSATION, TROISIÈME CHAMBRE CIVILE...    CHAMBRE_CIVILE_3
# 16      LA COUR DE CASSATION, PREMIÈRE CHAMBRE CIVILE,...    CHAMBRE_CIVILE_1
# 17      LA COUR DE CASSATION, PREMIÈRE CHAMBRE CIVILE,...    CHAMBRE_CIVILE_1
# 18      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 19      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 20      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 21      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 22      LA COUR DE CASSATION, TROISIÈME CHAMBRE CIVILE...    CHAMBRE_CIVILE_3
# 23      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 24      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 25      LA COUR DE CASSATION, PREMIÈRE CHAMBRE CIVILE,...    CHAMBRE_CIVILE_1
# 26      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 27      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# 28      LA COUR DE CASSATION, TROISIÈME CHAMBRE CIVILE...    CHAMBRE_CIVILE_3
# 29      LA COUR DE CASSATION, DEUXIÈME CHAMBRE CIVILE,...    CHAMBRE_CIVILE_2
# ...                                                   ...                 ...
# 247401  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247402  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247403  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247404  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247405  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247406  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247407  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247408  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247409  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247410  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247411  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247412  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247413  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247414  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247415  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247416  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247417  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247418  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247419  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247420  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247421  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247422  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247423  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247424  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247425  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247426  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247427  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247428  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247429  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
# 247430  LA COUR DE CASSATION, CHAMBRE CRIMINELLE, a re...  CHAMBRE_CRIMINELLE
#
#                                                 president  LABEL
# 0                                  M. Soulard (président)    1.0
# 1                                 M. Straehli (président)    1.0
# 2                                 M. Straehli (président)    1.0
# 3                                  M. Soulard (président)    1.0
# 4                                  M. Soulard (président)    1.0
# 5                                  M. Soulard (président)    1.0
# 6       M. Straehli (conseiller le plus ancien faisant...    1.0
# 7                                 M. Straehli (président)    1.0
# 8                                  M. Soulard (président)    1.0
# 9       M. Straehli (conseiller le plus ancien faisant...    1.0
# 10                                M. Straehli (président)    1.0
# 11                                M. Straehli (président)    1.0
# 12                                 M. Soulard (président)    1.0
# 13      Mme de la Lance (conseiller le plus ancien fai...    1.0
# 14                                M. Straehli (président)    1.0
# 15                                 M. Chauvin (président)    0.0
# 16                                  Mme Batut (président)    0.0
# 17                                  Mme Batut (président)    0.0
# 18                                  Mme Flise (président)    0.0
# 19                                  Mme Flise (président)    0.0
# 20                                  Mme Flise (président)    0.0
# 21                                  Mme Flise (président)    0.0
# 22                                 M. Chauvin (président)    0.0
# 23      Mme Maunand (conseiller le plus ancien faisant...    0.0
# 24      Mme Maunand (conseiller le plus ancien faisant...    0.0
# 25                                  Mme Batut (président)    0.0
# 26      Mme Maunand (conseiller le plus ancien faisant...    0.0
# 27      Mme Maunand (conseiller le plus ancien faisant...    0.0
# 28                                 M. Chauvin (président)    0.0
# 29      Mme Maunand (conseiller le plus ancien faisant...    0.0
# ...                                                   ...    ...
# 247401                             M. Soulard (président)    1.0
# 247402                             M. Soulard (président)    1.0
# 247403                             M. Soulard (président)    1.0
# 247404                             M. Soulard (président)    1.0
# 247405                             M. Soulard (président)    1.0
# 247406                             M. Soulard (président)    1.0
# 247407                             M. Soulard (président)    1.0
# 247408                             M. Soulard (président)    1.0
# 247409                             M. Soulard (président)    1.0
# 247410                             M. Soulard (président)    1.0
# 247411                             M. Soulard (président)    1.0
# 247412                             M. Soulard (président)    1.0
# 247413                             M. Soulard (président)    1.0
# 247414                             M. Soulard (président)    1.0
# 247415                             M. Soulard (président)    1.0
# 247416                             M. Soulard (président)    1.0
# 247417                             M. Soulard (président)    1.0
# 247418                             M. Soulard (président)    1.0
# 247419                             M. Soulard (président)    1.0
# 247420                             M. Soulard (président)    1.0
# 247421                             M. Soulard (président)    1.0
# 247422                             M. Soulard (président)    1.0
# 247423                             M. Soulard (président)    1.0
# 247424                             M. Soulard (président)    1.0
# 247425                             M. Soulard (président)    1.0
# 247426                             M. Soulard (président)    1.0
# 247427                             M. Soulard (président)    1.0
# 247428                             M. Soulard (président)    1.0
# 247429                             M. Soulard (président)    1.0
# 247430                             M. Soulard (président)    1.0
#
# [247431 rows x 5 columns]
# Found 382345 unique tokens.
# Train: N = 185573 records
# Test:  N = 61858 records

# %%
import pickle
with open("../models/saved_model.pickle", "rb") as file: # Use file to refer to the file object
    model_from_pickle = pickle.load(file)
    y_pred = model_from_pickle.predict(X_test)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.7 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# /home/pierre/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import confusion_matrix

y_pred = (y_pred > 0.5)
conf_mat = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=data.LABEL.values, yticklabels=data.LABEL.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX \n", size=16);
plt.show()

# %%
from sklearn import metrics

print('\t\t\t\tCLASSIFICATIION METRICS\n')
print(metrics.classification_report(y_test, y_pred, ))

# %%
for predicted in data["ID"]:
  for actual in data["ID"]:
    if predicted != actual and conf_mat[actual, predicted] >= 20:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], 
                                                           id_to_category[predicted], 
                                                           conf_mat[actual, predicted]))
    
      display(data.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['Product', 
                                                                'Consumer_complaint']])
      print('')
